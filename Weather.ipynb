# %%
import pandas as pd
data=pd.read_csv(r"/content/1. Weather Data.csv")
#here dataframe name is data
# data        #gives all data
# data.head() #gives 5 from top
# data.shape #gives total no of rows and colums of dataframe
# data.index        #index of dataframe
# data.columns      #gives name of each columns
# data.dtypes         #datatypes of each of column
# data['Weather'].unique()     #gives unique element present in a single coulmn not on whole dataframe
# data.nunique()#can be used on whole dataframe gives number of unique value can be applied on whole data frame or single column too
# data.count(); #gives total no of non-null val in each column can be applied on whole data frame or single column too
# data['Weather'].value_counts()  #can be applied on single column it shows all unique values with their count
# data.info() #gives all basic info of dataframe

# data.columns
# data.nunique();
# data.nunique();

# %%
data.columns
data.head()
data['Wind Speed_km/h'].unique()         
# data['Wind Speed_km/h'].nunique()  #34

# %% [markdown]
# # New Section

# %%
data.columns
# data['Weather'].value_counts()
data.Weather.value_counts()
data[data.Weather=="Clear"]
data.groupby('Weather').get_group('Clear')

# %%
data.head(2)
data[data['Wind Speed_km/h']==4]

# %%
# data.isnull().sum() 
# data.notnull().sum()
# data.rename(columns={'weather':'weather Condition'},inplace=True)
# data.head()

# %%
# mathematical functions
data.head()
data.Visibility_km.mean()
data.Press_kPa.std()
data['Rel Hum_%'].var()

# %%
#find instances when snow was recorded
data['Weather'].value_counts()
data[data['Weather']=='Snow']
data[data['Weather'].str.contains('Snow')].head(50)
data[data['Weather'].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# 8690   12/28/2012 2:00    -4.3              -6.3         86               11
# ...

# %%
#mean value of each column against Weather condition
data.groupby('Weather').mean()

# %%
#instances when wind speed is above 24 and visibility is 25
data[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==25)]

# %%
#min and max value of each column agains each weather condition
data.groupby('Weather').max()
data.groupby('Weather').min()

# %%
data[data['Weather']=='Fog']

# %%
data[(data['Weather']=='Clear')|(data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data[(data['Weather']=='Clear') & (data['Rel Hum_%']>50) | data['Visibility_km']>40]
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather]
# Index: []
